# %% [markdown]
# # Ingest Notebook

# %%
# Raw data path
raw_path = '/Volumes/databricks_telco_customer_dataset/v01/telco/telco-customer-churn.csv'
# Read data
raw_data = spark.read.option("header", True).option("inferSchema", True).csv(raw_path) 
display(raw_data.limit(5)) # Sample

# %%
# Schema description
raw_data.printSchema()

# %%
# Save raw data as table
raw_data.write.mode("overwrite").saveAsTable('workspace.telco.raw_data')
